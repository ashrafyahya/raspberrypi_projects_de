# %%
# !sudo apt-get install -y python3-pip python3-smbus i2c-tools
# Out:
# Paketlisten werden gelesen… Fertig
# Abhängigkeitsbaum wird aufgebaut… Fertig
# Statusinformationen werden eingelesen… Fertig
# python3-pip ist schon die neueste Version (23.0.1+dfsg-1+rpt1).
# python3-smbus ist schon die neueste Version (4.3-2+b3).
# python3-smbus wurde als manuell installiert festgelegt.
# i2c-tools ist schon die neueste Version (4.3-2+b3).
# i2c-tools wurde als manuell installiert festgelegt.
# 0 aktualisiert, 0 neu installiert, 0 zu entfernen und 1 nicht aktualisiert.

# %%
# !pip3 install adafruit-circuitpython-bme680
# Out:
# Looking in indexes: https://pypi.org/simple, https://www.piwheels.org/simple
# Collecting adafruit-circuitpython-bme680
#   Downloading https://www.piwheels.org/simple/adafruit-circuitpython-bme680/adafruit_circuitpython_bme680-3.7.8-py3-none-any.whl (10 kB)
# Collecting Adafruit-Blinka
#   Downloading https://www.piwheels.org/simple/adafruit-blinka/Adafruit_Blinka-8.46.1-py3-none-any.whl (355 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 355.3/355.3 kB 2.3 MB/s eta 0:00:000:00:010:00:01:01
# Collecting adafruit-circuitpython-busdevice
#   Downloading https://www.piwheels.org/simple/adafruit-circuitpython-busdevice/adafruit_circuitpython_busdevice-5.2.9-py3-none-any.whl (7.5 kB)
# Collecting Adafruit-PlatformDetect>=3.70.1
#   Downloading Adafruit_PlatformDetect-3.72.1-py3-none-any.whl (24 kB)
# Collecting Adafruit-PureIO>=1.1.7
#   Downloading https://www.piwheels.org/simple/adafruit-pureio/Adafruit_PureIO-1.1.11-py3-none-any.whl (10 kB)
# Collecting binho-host-adapter>=0.1.6
#   Downloading https://www.piwheels.org/simple/binho-host-adapter/binho_host_adapter-0.1.6-py3-none-any.whl (10 kB)
# Collecting pyftdi>=0.40.0
#   Downloading https://www.piwheels.org/simple/pyftdi/pyftdi-0.55.4-py3-none-any.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.6/145.6 kB 3.2 MB/s eta 0:00:000:00:01
# Collecting adafruit-circuitpython-typing
#   Downloading https://www.piwheels.org/simple/adafruit-circuitpython-typing/adafruit_circuitpython_typing-1.10.3-py3-none-any.whl (11 kB)
# Requirement already satisfied: RPi.GPIO in ./lib/python3.11/site-packages (from Adafruit-Blinka->adafruit-circuitpython-bme680) (0.7.1)
# Collecting rpi-ws281x>=4.0.0
#   Downloading rpi_ws281x-5.0.0.tar.gz (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.5/64.5 kB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting sysv-ipc>=1.1.0
#   Downloading sysv_ipc-1.1.0.tar.gz (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.4/99.4 kB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pyserial
#   Downloading https://www.piwheels.org/simple/pyserial/pyserial-3.5-py2.py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 1.9 MB/s eta 0:00:004.3 MB/s eta 0:00:01
# Collecting pyusb!=1.2.0,>=1.0.0
#   Downloading https://www.piwheels.org/simple/pyusb/pyusb-1.2.1-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 1.5 MB/s eta 0:00:00
# Collecting adafruit-circuitpython-requests
#   Downloading https://www.piwheels.org/simple/adafruit-circuitpython-requests/adafruit_circuitpython_requests-4.1.6-py3-none-any.whl (10 kB)
# Requirement already satisfied: typing-extensions~=4.0 in ./lib/python3.11/site-packages (from adafruit-circuitpython-typing->Adafruit-Blinka->adafruit-circuitpython-bme680) (4.12.2)
# Collecting Adafruit-Circuitpython-ConnectionManager
#   Downloading https://www.piwheels.org/simple/adafruit-circuitpython-connectionmanager/adafruit_circuitpython_connectionmanager-3.1.1-py3-none-any.whl (7.8 kB)
# Building wheels for collected packages: rpi-ws281x, sysv-ipc
#   Building wheel for rpi-ws281x (setup.py) ... done
#   Created wheel for rpi-ws281x: filename=rpi_ws281x-5.0.0-cp311-cp311-linux_aarch64.whl size=121648 sha256=41b7991322d31d182bab1f3cc0d6db1f45485eb64b7aa71f851fd66a740ab689
#   Stored in directory: /home/ashraf/.cache/pip/wheels/c8/b3/52/cfca661555719e40842e4f28b31e0e80a3f70677444c9adbd9
#   Building wheel for sysv-ipc (setup.py) ... done
#   Created wheel for sysv-ipc: filename=sysv_ipc-1.1.0-cp311-cp311-linux_aarch64.whl size=67987 sha256=9d73071622232607df7d454873816aad7c51a1b418265722c6daf860eefd02ee
#   Stored in directory: /home/ashraf/.cache/pip/wheels/49/6b/46/7e9cd45fc4d3818714fd36ffa22e8dec31d687861d77f9587e
# Successfully built rpi-ws281x sysv-ipc
# Installing collected packages: sysv-ipc, pyserial, Adafruit-PlatformDetect, rpi-ws281x, pyusb, binho-host-adapter, Adafruit-PureIO, pyftdi, Adafruit-Circuitpython-ConnectionManager, Adafruit-Blinka, adafruit-circuitpython-requests, adafruit-circuitpython-typing, adafruit-circuitpython-busdevice, adafruit-circuitpython-bme680
# Successfully installed Adafruit-Blinka-8.46.1 Adafruit-Circuitpython-ConnectionManager-3.1.1 Adafruit-PlatformDetect-3.72.1 Adafruit-PureIO-1.1.11 adafruit-circuitpython-bme680-3.7.8 adafruit-circuitpython-busdevice-5.2.9 adafruit-circuitpython-requests-4.1.6 adafruit-circuitpython-typing-1.10.3 binho-host-adapter-0.1.6 pyftdi-0.55.4 pyserial-3.5 pyusb-1.2.1 rpi-ws281x-5.0.0 sysv-ipc-1.1.0

# %%
import time
from board import *
import busio
import adafruit_bme680

# %%
# I2C initialisieren
print(SCL, SDA)
i2c = busio.I2C(SCL,SDA)


# BME680 Sensor initialisieren
bme680 = adafruit_bme680.Adafruit_BME680_I2C(i2c)

# Optional: Offset für die Umgebungstemperatur anpassen
bme680.sea_level_pressure = 1013.25

while True:
    print(f"Temperatur: {bme680.temperature:.2f} °C")
    time.sleep(2)
# Out:
# 3 2
